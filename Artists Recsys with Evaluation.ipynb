# %% [markdown]
# # ABOUT
#
# Million Musical Tweets Dataset: http://www.cp.jku.at/datasets/MMTD/
#
# Music Brainz: https://musicbrainz.org/doc/MusicBrainz_Database/Download
#
# Number of unique artists: 24673
#
# Number of unique users: 214741
#
# Number of unique tweets: 1074713
#
# Number of unique tracks: 133228
#
# ALS Implicit Collaborative Filtering: https://medium.com/radon-dev/als-implicit-collaborative-filtering-5ed653ba39fe

# %% [markdown]
# Artist Gender:
# 1 = Male
# 2 = Female
# 3 = Group
# 4 = Other
# 5 = No Info
#
# Artist Type:
# 1 = Person
# 2 = Group
# 3 = Other
# 4 = Character
# 5 = Choir
# 6 = No Info

# %%
import numpy as np
import pandas as pd
import scipy.sparse as sparse
import random
import math
import implicit
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KDTree

# %%
path = "/Users/MAC/Desktop/MIP 2019/Code/"
data = pd.read_csv(path+"data.csv", header = 0, sep=',', low_memory=False)
artist_gender = pd.read_csv(path+"gender_bias.csv", header = 0, sep=',')
artist_type = pd.read_csv(path + "artist_type.csv", header = 0, sep=',')
ttime = pd.read_csv(path+"ttime.csv", header = 0, sep=',')

# %%
#----------------------------------
BUILDING 2D RECOMMENDER SYSTEM 
#----------------------------------
alpha_val = 15
users = list(np.sort(data.user_id.unique()))
artists = list(data.artists_name.unique())
songs = list(data.track_title.unique())

data['usercatcode'] = data['user_id'].astype("category").cat.codes
data['artistcatcode'] = data['artist_id'].astype("category").cat.codes
data['ttime'] = data['tweet_time'].astype("category").cat.codes
data['songcatcode'] = data.track_title.astype('category', songs).cat.codes 
# Build train and test dataset
train, test = train_test_split(data, test_size=0.2)

# %%
#----------------------------------
# ARTISTS RECOMMENDATION MODEL 
#----------------------------------
artist_train = train.groupby(['user_id', 'artists_name', 'artistcatcode', 'usercatcode'])['tweet_id'].count().reset_index(name='tweet_count')
artist_data = data.groupby(['user_id', 'artists_name', 'artistcatcode', 'usercatcode'])['tweet_id'].count().reset_index(name='tweet_count')

# Create sparse matrices
sparse_artist_user = sparse.csr_matrix((artist_train['tweet_count'], (artist_train['artistcatcode'], artist_train['usercatcode'])))
sparse_user_artist = sparse.csr_matrix((artist_data['tweet_count'], (artist_data['usercatcode'], artist_data['artistcatcode'])))

# Calculate the confidence by multiplying it by our alpha value.
userartist_conf = (sparse_artist_user * alpha_val).astype('double')

# Initialize the als model_artist and fit it using the sparse artist-user matrix
model_artist = implicit.als.AlternatingLeastSquares(factors=20, regularization=0.1, iterations=50)
model_artist.fit(userartist_conf) 

# Caculate the sparsity of an item-user matrix
def sparsity(matrix):
    matrix_size = matrix.shape[0]*matrix.shape[1] # Number of possible interactions in the matrix
    num_purchases = len(matrix.nonzero()[0]) # Number of items interacted with
    sparsity = 100*(1 - (num_purchases/matrix_size))
    return sparsity

# %%
train_neighbor = pd.merge(train, ttime, on='user_id').drop(['tweet_id', 'track_id', 'track_title', 'artist_id', 'artists_name', 'artist_type', 'artist_area', 'artist_gender','tweet_month', 'tweet_year', 'tweet_time', 'tweet_day', 'usercatcode','artistcatcode', 'ttime', 'songcatcode', 'Total'], 1).drop_duplicates().set_index('user_id')
test_neighbor = ttime.drop('Total', 1).drop_duplicates().set_index('user_id')
tree = KDTree(train_neighbor.values, leaf_size=80)
dist, ind = tree.query(test_neighbor, k = 20)

# %%
#-----------------------------------------------
# IMPLICIT COLLABORATIVE FILTERING SYSTEM
#-----------------------------------------------

# FIND SIMILAR ARTISTS

def similar_artists_func(artist=random.choice(artists), N = 10): 
    testartist = data.artistcatcode.loc[data.artists_name == artist].iloc[0]

    # Use implicit to get similar items.
    similar = model_artist.similar_items(testartist, n_similar)
    
    # Print the names of our most similar artists
    print('{} similar artists to {}:'.format(n_similar, name))
    max_similarity = similar[0][1]
    for item in similar:
        idx, score = item
        percentage = (score / max_similarity) * 100
        name = data.artists_name.loc[data.artistcatcode == idx].iloc[0]
        print(name, "- with a similarity of {:.2f}%".format(percentage))

# CREATE RECOMMENDATIONS FOR USER
       
def cf_recsys(user_id=testuser, N = 15):
    testuser = data.usercatcode.loc[data.user_id == user_id].iloc[0]
    recommended = model_artist.recommend(testuser, sparse_user_artist, N)
    recommendation = dict()
    for idx, score in recommended:
        aname = data.artists_name.loc[data.artistcatcode == idx].iloc[0]
        recommendation[aname] = score.round(3)
    recommendation = sorted(recommendation.items(), key=lambda x: x[1], reverse=True)
    return recommendation

# %%
#------------------
# HYBRID SYSTEMS
#------------------

def hybrid_recsys(user_id=testuser, N=15):
        # Create recommendations for user with user_id 161262801
    testuser = data.usercatcode.loc[data.user_id == user_id].iloc[0]
        # Use the implicit recommender.
    recommended = model_artist.recommend(testuser, sparse_user_artist, N)
        # Get artist names from ids
    recommendation = dict()
    for idx, score in recommended:
            #get artist name
        aname = data.artists_name.loc[data.artistcatcode == idx].iloc[0]
            #get gender bias weight for that artist
        agender = data.artist_gender.loc[data.artistcatcode == idx].iloc[0]
        ag_bias = artist_gender[agender].loc[artist_gender.user_id == user_id].iloc[0]
            #get type bias weight for that artist
        atype = data.artist_type.loc[data.artistcatcode == idx].iloc[0]
        atype_bias = artist_type[atype].loc[artist_type.user_id == user_id].iloc[0]
            #update the final score
        fscore = score*(1 + ag_bias + atype_bias)
            #append results to lists
        recommendation[aname] = fscore.round(3)
            #print out the results
    recommendation = sorted(recommendation.items(), key=lambda x: x[1], reverse=True)[:N]
    return recommendation

# %%
#--------------------------
# CONTEXT-AWARE SYSTEMS
#--------------------------
def context_recsys(user_id=testuser, N=15):
        #build neighborlist
    ix = test_neighbor.index.get_loc(user_id)
    n_id = test_neighbor.index[ind[ix]].values
    sim_score = 1 - dist[ix]
    neighborlist = list(zip(n_id, sim_score))
        #build recommendation for each neighbor
    recommendation = dict()
    a_counter = dict()
    for neighbor, sim in neighborlist:
        hybrid = hybrid_recsys(neighbor)
        for artist, score in hybrid: 
            if neighbor == user_id: 
                fscore = score * 3
            else: 
                fscore = score * (1 + sim)
            if artist in recommendation.keys():
                a_counter[artist] =+ 1
                recommendation[artist] = max(recommendation[artist], fscore)
            else: 
                a_counter[artist] = 1
                recommendation[artist] = fscore.round(3)
    for artist in recommendation.keys(): 
        recommendation[artist] = recommendation[artist] + math.log(a_counter[artist])
    recommendation = sorted(recommendation.items(), key=lambda x: x[1], reverse=True)[:N]
    return recommendation

# %%
#------------------
# EVALUATION
#------------------
def fmeasure(user=testuser, system=context_recsys):
    recommend_artist = [i[0] for i in system(user)]
    real_artist = set(data[data['user_id'] == user]['artist_name'])
    match = real_artist.intersection(recommend_artist)
    precision = len(match)/len(recommend_artist) 
    recall = len(match)/len(real_artist)
    if precision + recall == 0:
        f1_score = 0
    else:
        f1_score = 2 * (precision * recall) / (precision + recall)
    return f1_score
def comparison(user=testuser):
    print('user: ', user, '\n')
    print('CF System: ', fmeasure(user, cf_recsys))
    print('Hybrid System: ', fmeasure(user, hybrid_recsys))
    print('Context System: ', fmeasure(user, context_recsys))

# %%
results = []
for user in users: 
    d = dict()
    d['user_id'] = user
    d['CF System'] = fmeasure(user, cf_recsys)
    d['Hybrid System: '] = fmeasure(user, hybrid_recsys)
    d['Context System: '] = fmeasure(user, context_recsys)
    results.append(d)

# %%
results
# Out:
# [{'user_id': 335, 'CF System': 0, 'Hybrid System: ': 0, 'Context System: ': 0},
#  {'user_id': 855, 'CF System': 0, 'Hybrid System: ': 0, 'Context System: ': 0},
#  {'user_id': 2695,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3249,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.1111111111111111},
#  {'user_id': 5212,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5976,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10440,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.018867924528301886},
#  {'user_id': 11140,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 11526,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 11916,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 11979,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 12771,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 12924,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 13152,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 20503,
#   'CF System': 0.11764705882352941,
#   'Hybrid System: ': 0.11764705882352941,
#   'Context System: ': 0},
#  {'user_id': 21803,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 23493,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 27603,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 29283,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 42753,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 45523,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 46713,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 55913,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 61323,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 67013,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 71763,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 115053,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 615723,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 625263,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 632323,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 637393,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 649473,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 659103,
#   'CF System': 0.11764705882352941,
#   'Hybrid System: ': 0.11764705882352941,
#   'Context System: ': 0.11764705882352941},
#  {'user_id': 661243,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 665563,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 679763,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 700673,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 701233,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 702253,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 704953,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 711093,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 711803,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 714023,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 718993,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 748993,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 754636,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 754714,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 757053,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 758734,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 766122,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 768670,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 775336,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 776260,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 784999,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 800887,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 802354,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 802566,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 804376,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 809524,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 811260,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 814314,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 820922,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.08695652173913045},
#  {'user_id': 865381,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 866481,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 913381,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 919581,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 949101,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 953811,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 978101,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1000531,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1004891,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1024691,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1092231,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1142311,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1165651,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1216691,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1236481,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1257731,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1291681,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1473861,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1502181,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1552431,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1558311,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1559741,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1580981,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1584271,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1588551,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1668501,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1668541,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1719601,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1734411,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1840681,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1848451,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1852301,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1935681,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1937281,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1970351,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 1991961,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2040191,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2045421,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2093671,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2128421,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2148401,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2213461,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2236711,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2250261,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2273461,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2292361,
#   'CF System': 0.125,
#   'Hybrid System: ': 0.125,
#   'Context System: ': 0},
#  {'user_id': 2297061,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.09523809523809522},
#  {'user_id': 2358011,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2364531,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2365991,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2467201,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2476311,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2702381,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2707991,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2771391,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2939361,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2950331,
#   'CF System': 0.11764705882352941,
#   'Hybrid System: ': 0.11764705882352941,
#   'Context System: ': 0},
#  {'user_id': 2986821,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 2990991,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3086851,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3104781,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.0625},
#  {'user_id': 3203071,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3225751,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3241911,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3277541,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3308031,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3349081,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3365291,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3372471,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3394701,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3398201,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3401711,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3429221,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3432881,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3433441,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3504691,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3579811,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.1},
#  {'user_id': 3628371,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3630121,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3664351,
#   'CF System': 0.125,
#   'Hybrid System: ': 0.125,
#   'Context System: ': 0.125},
#  {'user_id': 3751601,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3828031,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3832121,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3848671,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 3873181,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 4041161,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 4312711,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 4347511,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 4351561,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 4436021,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 4468471,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 4491661,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 4668111,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 4932691,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 4964311,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5146561,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5152581,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5268001,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5282232,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5351422,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.24},
#  {'user_id': 5388102,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5397812,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5402652,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5413652,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5454282,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5469512,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5509092,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5570362,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5631932,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5633032,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5656862,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5659712,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5667022,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5669992,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5670112,
#   'CF System': 0.1111111111111111,
#   'Hybrid System: ': 0.1111111111111111,
#   'Context System: ': 0.1111111111111111},
#  {'user_id': 5671982,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5685462,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5694792,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5697742,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5707772,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5717182,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5733292,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5736542,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5737772,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5742962,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5744522,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5756352,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5766802,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5787162,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5791062,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5804262,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5830382,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5845592,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5869822,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5938472,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5950632,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5958592,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 5961732,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6073322,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6087762,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6091042,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6093112,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6107552,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6110802,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6112422,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6116782,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6169902,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6174362,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6177732,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6179532,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.125},
#  {'user_id': 6184842,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6187102,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.09090909090909091},
#  {'user_id': 6212032,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6234332,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6267622,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6276902,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6284612,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6287392,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6296142,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6309152,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6320262,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6348722,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6349582,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6380812,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6399462,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6425262,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6426912,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6434092,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6443902,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6471142,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6472732,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6473232,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6488282,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6490262,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6504262,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6506302,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6509982,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6529302,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6531532,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6538372,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6576902,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6583942,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6644082,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6662252,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6685882,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6696282,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6696362,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6729782,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6745932,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6751172,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6792212,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6794292,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6806292,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6815762,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6830602,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6838672,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6845602,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6852982,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6854382,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6854632,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6856622,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6869022,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6882312,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6889532,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6902052,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6959062,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6960862,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 6977872,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.11764705882352941},
#  {'user_id': 6982192,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7034222,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7036192,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7042752,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7047382,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7072362,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.11764705882352941},
#  {'user_id': 7074622,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7121742,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.125},
#  {'user_id': 7168892,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7170322,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7189552,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7190462,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7197432,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7204882,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7205832,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7224492,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7224742,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7242432,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7244302,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7319332,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7322102,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7331672,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7333982,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7345092,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7379562,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7380142,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7394072,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7397482,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7404982,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7431192,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7445912,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7446652,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7465732,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7471312,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7481922,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7507762,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7533012,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7534432,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7548472,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7586892,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7606742,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7614922,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7636802,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7654442,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7655682,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7656722,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7665242,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7667752,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7691032,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7697072,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7732142,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7732462,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7759612,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7776792,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7798732,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7822892,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.125},
#  {'user_id': 7833572,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7835792,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7840492,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7852222,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7852602,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7882872,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7897722,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7898342,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7902502,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7912362,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.09090909090909091},
#  {'user_id': 7921222,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7955882,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7959462,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7971082,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 7985162,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8023282,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.0425531914893617},
#  {'user_id': 8028942,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8055012,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8059572,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8065592,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8065652,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8073822,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8076732,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8125752,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.1111111111111111},
#  {'user_id': 8148972,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8151272,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8169342,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8198082,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8214772,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.125},
#  {'user_id': 8220322,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8221502,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8261872,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8284852,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8291932,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8329172,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8354292,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8356242,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.11764705882352941},
#  {'user_id': 8358992,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8384632,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8396712,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8399422,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8409382,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8420142,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8450062,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8497262,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8538272,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8544622,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8571212,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8593942,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8608182,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.125},
#  {'user_id': 8619132,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8625112,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8632372,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8646962,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8649652,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8660462,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8673152,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8714402,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8739412,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8745762,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8775322,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8830542,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8854072,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8903272,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8906832,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8911572,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8927962,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.11764705882352941},
#  {'user_id': 8930862,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8939362,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8962952,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8980062,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 8989992,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9004862,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9025622,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9032692,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9093402,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9116092,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9132012,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9134532,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9137212,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9145522,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9146202,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9188692,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9192022,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9196252,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9206312,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9258752,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9275002,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.10526315789473685},
#  {'user_id': 9286712,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9297952,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9307612,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9308442,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9336412,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9361892,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9368052,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9412982,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9415962,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9419912,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9423932,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9439332,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9451052,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9530552,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9536242,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9545542,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9563312,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9564002,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9565442,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9582012,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9603052,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9640552,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9683332,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9689852,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.09523809523809522},
#  {'user_id': 9726632,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9769112,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9777822,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9798732,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9862172,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9899682,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9902302,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9922382,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9957642,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 9960702,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10021182,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10021212,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10025942,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10076552,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10090992,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10132022,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10137202,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10152402,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10165562,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10168922,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10205602,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.125},
#  {'user_id': 10223472,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10229352,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10250632,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10258492,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10271962,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10273412,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10286042,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.07142857142857144},
#  {'user_id': 10292942,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10295432,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10296692,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10323112,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10337182,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10368562,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10375542,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10380672,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10393812,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10411962,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10412742,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10451082,
#   'CF System': 0.11764705882352941,
#   'Hybrid System: ': 0.11764705882352941,
#   'Context System: ': 0.11764705882352941},
#  {'user_id': 10461152,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10497342,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10511132,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10515042,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10526082,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10557112,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10557212,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10559742,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10642142,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10647022,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10673592,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10680482,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.125},
#  {'user_id': 10699112,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10750072,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10774762,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10778382,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10780742,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10793022,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10793472,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10794282,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10796982,
#   'CF System': 0.125,
#   'Hybrid System: ': 0.125,
#   'Context System: ': 0},
#  {'user_id': 10802742,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10806902,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10845582,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.05},
#  {'user_id': 10853812,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10916802,
#   'CF System': 0.1111111111111111,
#   'Hybrid System: ': 0.1111111111111111,
#   'Context System: ': 0.1111111111111111},
#  {'user_id': 10920812,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.11764705882352941},
#  {'user_id': 10928552,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10948812,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10977932,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 10994802,
#   'CF System': 0.1,
#   'Hybrid System: ': 0.1,
#   'Context System: ': 0},
#  {'user_id': 11013512,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 11019192,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 11044592,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 11059162,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 11062162,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.0689655172413793},
#  {'user_id': 11070512,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 11087102,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 11094232,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 11141762,
#   'CF System': 0.11764705882352941,
#   'Hybrid System: ': 0.11764705882352941,
#   'Context System: ': 0},
#  {'user_id': 11144832,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 11170602,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 11174782,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 11192532,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 11210972,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 11237842,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 11250442,
#   'CF System': 0.13333333333333333,
#   'Hybrid System: ': 0.13333333333333333,
#   'Context System: ': 0},
#  {'user_id': 11269862,
#   'CF System': 0,
# ...
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.1},
#  {'user_id': 14382506,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14382816,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14383171,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14383511,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14383582,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14388155,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.11764705882352941},
#  {'user_id': 14393762,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.07692307692307691},
#  {'user_id': 14393766,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14397801,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14398909,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14399280,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14407517,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14409456,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14409518,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14411894,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14416388,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14418456,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14419736,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14426127,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14426310,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14426391,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14426558,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14426605,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14426643,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14426695,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14426827,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14429526,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14432272,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14434019,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14435796,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14439724,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14443016,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.0606060606060606},
#  {'user_id': 14444396,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14444901,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14446495,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14447244,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14447615,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.11764705882352941},
#  {'user_id': 14449409,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14451534,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14451823,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.11764705882352941},
#  {'user_id': 14454279,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14455869,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14457479,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14458407,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14462052,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14465598,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14466878,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14467264,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14468893,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14470833,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14473676,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14478145,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14481336,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14485604,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14491335,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14491444,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14494407,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14494764,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14495000,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14497080,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14497584,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14500034,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14503089,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14503412,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14507697,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14508135,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14509009,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14510008,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14513289,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14515014,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14520061,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14522996,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.10526315789473685},
#  {'user_id': 14526141,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14529574,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14530466,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14533279,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14534530,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14534810,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14538474,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14540439,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14541013,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14544064,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14546512,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14551263,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14555534,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14560819,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14564948,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14565811,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14567706,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14568850,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14568927,
#   'CF System': 0.125,
#   'Hybrid System: ': 0.125,
#   'Context System: ': 0},
#  {'user_id': 14569277,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14569475,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14569609,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14570923,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14572895,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14573719,
#   'CF System': 0.125,
#   'Hybrid System: ': 0.125,
#   'Context System: ': 0},
#  {'user_id': 14574170,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14574805,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14577254,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14577982,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14579233,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14588213,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14588309,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14588595,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14593303,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14594844,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14600962,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14601026,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.11764705882352941},
#  {'user_id': 14604598,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14606973,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14611488,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14611544,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14611817,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14612265,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14612987,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14613463,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14614399,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14615329,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14617248,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14620469,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14621842,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14624114,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14625286,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14632730,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14637193,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14642792,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14644247,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14647022,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14648839,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14649375,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14650541,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.17647058823529413},
#  {'user_id': 14655980,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14657047,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14657572,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14659979,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14662121,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14663011,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14665785,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14669856,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14670872,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14671694,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14673205,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14675160,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14677055,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14679555,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14679796,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14681731,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14684439,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14684896,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14685098,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14686400,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.1111111111111111},
#  {'user_id': 14687553,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14689593,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14692263,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14694082,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14698676,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14700070,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14702612,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14703612,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14710973,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14711094,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14715163,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14715893,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14718153,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14720050,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14724501,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14725558,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14728044,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14729050,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14729403,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14729423,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 14731961,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  ...]

# %%
testsetresults = []
for user in test.user_id.unique(): 
    d = dict()
    d['user_id'] = user
    d['CF System'] = fmeasure(user, cf_recsys)
    d['Hybrid System: '] = fmeasure(user, hybrid_recsys)
    d['Context System: '] = fmeasure(user, context_recsys)
    testsetresults.append(d)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-101-a6bb31cb877a> in <module>
#       5     d['CF System'] = fmeasure(user, cf_recsys)
#       6     d['Hybrid System: '] = fmeasure(user, hybrid_recsys)
# ----> 7     d['Context System: '] = fmeasure(user, context_recsys)
#       8     testsetresults.append(d)
#
# <ipython-input-63-687bfa48138c> in fmeasure(user, system)
#       1 def fmeasure(user=testuser, system=context_recsys):
# ----> 2     recommend_artist = [i[0] for i in system(user)]
#       3     real_artist = set(data[data['user_id'] == user]['artists_name'])
#       4     match = real_artist.intersection(recommend_artist)
#       5     precision = len(match)/len(recommend_artist)
#
# <ipython-input-96-f7a77c44fda2> in context_recsys(user_id, N)
#      12     a_counter = dict()
#      13     for neighbor, sim in neighborlist:
# ---> 14         hybrid = hybrid_recsys(neighbor)
#      15         for artist, score in hybrid:
#      16             if neighbor == user_id:
#
# <ipython-input-50-5b8328a6c325> in hybrid_recsys(user_id, N)
#      15             #get gender bias weight for that artist
#      16         agender = data.artist_gender.loc[data.artistcatcode == idx].iloc[0]
# ---> 17         ag_bias = artist_gender[agender].loc[artist_gender.user_id == user_id].iloc[0]
#      18             #get type bias weight for that artist
#      19         atype = data.artist_type.loc[data.artistcatcode == idx].iloc[0]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1191                              "Series objects")
#    1192
# -> 1193         elif is_categorical_dtype(self):
#    1194             # Dispatch to Categorical implementation; pd.CategoricalIndex
#    1195             # behavior is non-canonical GH#19513
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     541     if arr_or_dtype is None:
#     542         return False
# --> 543     return CategoricalDtype.is_dtype(arr_or_dtype)
#     544
#     545
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/base.py in is_dtype(cls, dtype)
#      82            conditions is true for ``dtype.dtype``.
#      83         """
# ---> 84         dtype = getattr(dtype, 'dtype', dtype)
#      85
#      86         if isinstance(dtype, np.dtype):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in dtype(self)
#     413     def dtype(self):
#     414         """ return the dtype object of the underlying data """
# --> 415         return self._data.dtype
#     416
#     417     @property
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in dtype(self)
#    4718     @property
#    4719     def dtype(self):
# -> 4720         return self._block.dtype
#    4721
#    4722     @property
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in dtype(self)
#     350         return self.values.shape
#     351
# --> 352     @property
#     353     def dtype(self):
#     354         return self.values.dtype
#
# KeyboardInterrupt:

# %%
testsetresults
# Out:
# [{'user_id': 160006761,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 160874621,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.0024420024420024424},
#  {'user_id': 44396766,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.11764705882352941},
#  {'user_id': 64679715,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.07407407407407407},
#  {'user_id': 475244038,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.08333333333333334},
#  {'user_id': 81232966,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 161262801,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 99905361,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 104229368,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 147606305,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 84013497,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 44934729,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 477227497,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 300949796,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 22531089,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 174194590,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.004413928396272683},
#  {'user_id': 367742359,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 273012018,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.27906976744186046},
#  {'user_id': 26432623,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.0035273368606701942},
#  {'user_id': 143599427,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 119596431,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0},
#  {'user_id': 18342439,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.09090909090909091},
#  {'user_id': 97028006,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.1379310344827586},
#  {'user_id': 174626103,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0.005306799336650082},
#  {'user_id': 242191803,
#   'CF System': 0,
#   'Hybrid System: ': 0,
#   'Context System: ': 0}]
